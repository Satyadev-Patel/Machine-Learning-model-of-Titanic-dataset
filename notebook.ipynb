# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("C:\\Users\\SATYADEV\\Documents\\Untitled Folder\\train.csv")
test = pd.read_csv("C:\\Users\\SATYADEV\\Documents\\Untitled Folder\\test.csv")
test['Survived'] = 1

# %%
df = train.append(test)
sf = df

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         1       3
# 414         1306         1       1
# 415         1307         1       3
# 416         1308         1       3
# 417         1309         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 132.9+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.580596     2.294882    29.881138     0.498854
# std     378.020061     0.493650     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     1.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
x = train[train['Survived']==1]

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
x['Sex'].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
x['SibSp'].value_counts()
# Out:
# 0    210
# 1    112
# 2     13
# 3      4
# 4      3
# Name: SibSp, dtype: int64

# %%
x['Parch'].value_counts()
# Out:
# 0    233
# 1     65
# 2     40
# 3      3
# 5      1
# Name: Parch, dtype: int64

# %%
x['Age'].hist(bins = 50)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train['Fare'].hist(bins = 50)

# %%
x['Pclass'].value_counts()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         1       3
# 414         1306         1       1
# 415         1307         1       3
# 416         1308         1       3
# 417         1309         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].fillna(df['Age'].median(),inplace = True)
sf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         1       3
# 414         1306         1       1
# 415         1307         1       3
# 416         1308         1       3
# 417         1309         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df = df.drop(columns = ['Ticket','Cabin','PassengerId'])

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 413         1       3                                 Spector, Mr. Woolf
# 414         1       1                       Oliva y Ocana, Dona. Fermina
# 415         1       3                       Saether, Mr. Simon Sivertsen
# 416         1       3                                Ware, Mr. Frederick
# 417         1       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch      Fare Embarked
# ...

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        1
# Embarked    2
# dtype: int64

# %%
df['Fare'].fillna(df['Fare'].median(),inplace=True)

# %%
df['Embarked'].fillna('S',inplace = True)

# %%
df.isnull().sum(0)
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df['Family'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 413         1       3                                 Spector, Mr. Woolf
# 414         1       1                       Oliva y Ocana, Dona. Fermina
# 415         1       3                       Saether, Mr. Simon Sivertsen
# 416         1       3                                Ware, Mr. Frederick
# 417         1       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch      Fare Embarked  Family
# ...

# %%
x = df[df['Survived']==1]

# %%
x['Family'].hist(bins = 50)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 413         1       3                                 Spector, Mr. Woolf
# 414         1       1                       Oliva y Ocana, Dona. Fermina
# 415         1       3                       Saether, Mr. Simon Sivertsen
# 416         1       3                                Ware, Mr. Frederick
# 417         1       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch      Fare Embarked  Family
# ...

# %%
df.describe()
# Out:
#           Survived       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      0.580596     2.294882    29.503186     0.498854     0.385027
# std       0.493650     0.837836    12.905241     1.041658     0.865560
# min       0.000000     1.000000     0.170000     0.000000     0.000000
# 25%       0.000000     2.000000    22.000000     0.000000     0.000000
# 50%       1.000000     3.000000    28.000000     0.000000     0.000000
# 75%       1.000000     3.000000    35.000000     1.000000     0.000000
# max       1.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare       Family
# count  1309.000000  1309.000000
# mean     33.281086     0.883881
# std      51.741500     1.583639
# min       0.000000     0.000000
# 25%       7.895800     0.000000
# 50%      14.454200     0.000000
# 75%      31.275000     1.000000
# max     512.329200    10.000000

# %%
hf = df

# %%
hf
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 413         1       3                                 Spector, Mr. Woolf
# 414         1       1                       Oliva y Ocana, Dona. Fermina
# 415         1       3                       Saether, Mr. Simon Sivertsen
# 416         1       3                                Ware, Mr. Frederick
# 417         1       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch      Fare Embarked  Family
# ...

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Sex','Embarked'] 
le = LabelEncoder()
for i in var_mod:
    hf[i] = le.ﬁt_transform(hf[i].astype(str))

# %%
hf
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 413         1       3                                 Spector, Mr. Woolf    1
# 414         1       1                       Oliva y Ocana, Dona. Fermina    0
# 415         1       3                       Saether, Mr. Simon Sivertsen    1
# 416         1       3                                Ware, Mr. Frederick    1
# 417         1       3                           Peter, Master. Michael J    1
#
# ...

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.linear_model import LinearRegression
#from sklearn.cross_validation import KFold  
from sklearn.model_selection import KFold 
#new versions of python support this, if old then use above comment 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor, export_graphviz 
from sklearn import metrics

# %%
def classification_model(model, data, predictors, outcome):  
    #Fit the model:  
    model.fit(data[predictors],data[outcome])    
    #Make predictions on training set:  
    predictions = model.predict(data[predictors])
    #Print accuracy  
    accuracy = metrics.accuracy_score(predictions,data[outcome])  
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
    #RMSE = metrics.mean_squared_error(predictions,data[outcome])  
    #R2 = metrics.r2_score(predictions,data[outcome])
    #print("R2  ",R2)
    #Perform k-fold cross-validation with 5 folds  
    kf = KFold(5,shuffle=True)  
    error = []  
    for train, test in kf.split(data):
        # Filter training data    
        train_predictors = (data[predictors].iloc[train,:]) 
        # The target we're using to train the algorithm.    
        train_target = data[outcome].iloc[train]        
        # Training the algorithm using the predictors and target.    
        model.fit(train_predictors, train_target)       
        #Record error from each cross-validation run    
        error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
    print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error))) 
    # %s is placeholder for data from format, next % is used to conert it into percentage
    #.3% is no. of decimals

# %%
new_train = hf.iloc[0:len(train)]
new_test = hf.iloc[len(train):len(hf)]
new_train
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...

# %%
predictor_var = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked','Family']
outcome_var = ['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
model = DecisionTreeClassifier(ccp_alpha = 0.01)
classification_model(model, new_train,predictor_var,outcome_var)
# Out:
# Accuracy : 81.930%
# Cross-Validation Score : 80.918%

# %%
model = RandomForestClassifier(max_depth = 7,n_estimators = 100)
classification_model(model, new_train,predictor_var,outcome_var)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# Accuracy : 88.889%
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
result = model.predict(new_test[predictor_var])
np.savetxt("foo.csv", result, delimiter=",")

# %%
featimp = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False) 
print(featimp)
# Out:
# Sex         0.383850
# Fare        0.193119
# Age         0.150154
# Pclass      0.113823
# Family      0.065066
# SibSp       0.038723
# Parch       0.028141
# Embarked    0.027125
# dtype: float64
